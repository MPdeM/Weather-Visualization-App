# %%
import pandas as pd

# %%
#read data as df
df = pd.read_csv('Resources/cities20191207-203932.csv')
df.head()
# Out:
#    Unnamed: 0          City  Cloudiness % Country        Date  Humidity %  \
# 0           0    Butaritari           100      KI  1575768372          95
# 1           1         Bluff            12      AU  1575768373          24
# 2           2    Den Helder            75      NL  1575768374          87
# 3           3          Chuy             1      UY  1575768375          83
# 4           4  Punta Arenas           100      CL  1575768270          81
#
#    Latitude  Longitude  Max Temp (F)  Wind Speed (mph)
# 0      3.07     172.79         75.85             10.80
# 1    -23.58     149.07         89.94              6.82
# 2     52.96       4.76         51.01             28.86
# 3    -33.69     -53.46         56.53              7.25
# 4    -53.16     -70.91         46.40             12.75

# %%
df=df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#            City  Cloudiness % Country        Date  Humidity %  Latitude  \
# 0    Butaritari           100      KI  1575768372          95      3.07
# 1         Bluff            12      AU  1575768373          24    -23.58
# 2    Den Helder            75      NL  1575768374          87     52.96
# 3          Chuy             1      UY  1575768375          83    -33.69
# 4  Punta Arenas           100      CL  1575768270          81    -53.16
#
#    Longitude  Max Temp (F)  Wind Speed (mph)
# 0     172.79         75.85             10.80
# 1     149.07         89.94              6.82
# 2       4.76         51.01             28.86
# 3     -53.46         56.53              7.25
# 4     -70.91         46.40             12.75

# %%
#transform data as html

html_table = df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Cloudiness %</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Humidity %</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Max Temp (F)</th>\n      <th>Wind Speed (mph)</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Butaritari</td>\n      <td>100</td>\n      <td>KI</td>\n      <td>1575768372</td>\n      <td>95</td>\n      <td>3.07</td>\n      <td>172.79</td>\n      <td>75.85</td>\n      <td>10.80</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Bluff</td>\n      <td>12</td>\n      <td>AU</td>\n      <td>1575768373</td>\n      <td>24</td>\n      <td>-23.58</td>\n      <td>149.07</td>\n      <td>89.94</td>\n      <td>6.82</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Den Helder</td>\n      <td>75</td>\n      <td>NL</td>\n      <td>1575768374</td>\n      <td>87</td>\n      <td>52.
# ...

# %%
df.to_html('table.html')
